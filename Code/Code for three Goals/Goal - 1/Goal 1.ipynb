# %%
import pandas as pd

# %%
data = pd.read_csv('AllTweets_Combined.csv')
data
# Out:
#                Created At                                               Text
# 0        09-03-2021 23:59  b"RT @beatlesstory: Happy Birthday Suga! \xf0\...
# 1        09-03-2021 23:59      b'@Barnie_Replys @bts_bighit Check your sock'
# 2        09-03-2021 23:59  b'RT @schwarmmysays: @mrkate @bts_bighit Lots ...
# 3        09-03-2021 23:59  b"RT @beatlesstory: Happy Birthday Suga! \xf0\...
# 4        09-03-2021 23:59  b'RT @mollajoon: how do you except bighit arti...
# ...                   ...                                                ...
# 3808  2021-03-13 23:49:18  b'RT @NBA_AU: Another big night for @Patty_Mil...
# 3809  2021-03-13 23:49:17  b'that should just inspire other owners to:\nA...
# 3810  2021-03-13 23:49:09  b'Just remembered that #NorthLondonDerby aka t...
# 3811  2021-03-13 23:49:07  b'RT @siezethehay: \xe2\x80\x98Exciting place ...
# 3812  2021-03-13 23:49:00  b'@ibbyman27 @amaru1994 @clutchfans Yes you ca...
#
# [3813 rows x 2 columns]

# %%
#Importing Necessary Libraries for Text Processing
import nltk
from nltk.corpus import stopwords

# %%
#Downloading Stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\basua\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Load English Stop Words
stopword = stopwords.words('english')
print("Stopwords:",stopword)
# Out:
# Stopwords: ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 's
# ...

# %%
import re,string
#Tweet Clean Function
def tweet_clean(twee):
    #Remove URL
    twee = re.sub(r'https?://\S+|www\.\S+', " ", twee)

    #Remove Mentions
    twee = re.sub(r'@\w+',' ',twee)

    #Remove Punctuation
    twee= re.sub(r'[^\w\s\d]',' ',twee)

    #Remove Digits
    twee = re.sub(r'\d+', ' ', twee)

    #Remove HTML tags
    twee = re.sub('r<.*?>',' ', twee)

    #Remove Hastags
    twee = re.sub(r'#\w+', ' ', twee)

    #Remove Stop Words 
    twee = twee.split()
    #twee = " ".join(twee)
    
    twee = " ".join([word for word in twee if not word in stopword])

    return twee

# %%
#Applying Tweet Clean Function to Both Files
data['Text'] = data['Text'].astype(str).apply(lambda x: tweet_clean(x))

# %%
data
# Out:
#                Created At                                               Text
# 0        09-03-2021 23:59  b RT Happy Birthday Suga xf x f x e x n nSuga ...
# 1        09-03-2021 23:59                                       b Check sock
# 2        09-03-2021 23:59  b RT Lots purple galaxy stuff namjoon hand wri...
# 3        09-03-2021 23:59  b RT Happy Birthday Suga xf x f x e x n nSuga ...
# 4        09-03-2021 23:59        b RT except bighit artists chaotic ceo like
# ...                   ...                                                ...
# 3808  2021-03-13 23:49:18  b RT Another big night bench win xf x f x xaa ...
# 3809  2021-03-13 23:49:17   b inspire owners nA Show ambition nB Sell xe x x
# 3810  2021-03-13 23:49:09  b Just remembered NorthLondonDerby aka Clowns ...
# 3811  2021-03-13 23:49:07  b RT xe x x Exciting place NASDAQ There xe x x...
# 3812  2021-03-13 23:49:00  b Yes never fan harden I know real After Spur ...
#
# [3813 rows x 2 columns]

# %%
data1 = data.iloc[0:100]
data2 = data.iloc[100:200]
data3 = data.iloc[200:300]
data4 = data.iloc[300:400]
data5 = data.iloc[400:500]
data6 = data.iloc[500:532]
data7 = data.iloc[532:632]
data8 = data.iloc[632:732]
data9 = data.iloc[732:832]
data10 = data.iloc[832:932]

data11 = data.iloc[932:1032]
data12 = data.iloc[1032:1132]
data13 = data.iloc[1132:1232]
data14 = data.iloc[1232:1332]
data15 = data.iloc[1332:1432]
data16 = data.iloc[1432:1532]
data17 = data.iloc[1532:1632]
data18 = data.iloc[1632:1732]
data19 = data.iloc[1732:1832]
data20 = data.iloc[1832:1932]

data21 = data.iloc[1932:2009]
data22 = data.iloc[2009:2109]
data23 = data.iloc[2109:2209]
data24 = data.iloc[2209:2309]
data25 = data.iloc[2309:2409]
data26 = data.iloc[2409:2509]
data27 = data.iloc[2509:2513]
data28 = data.iloc[2513:2613]
data29 = data.iloc[2613:2713]
data30 = data.iloc[2713:2813]

data31 = data.iloc[2813:2913]
data32 = data.iloc[2913:3013]
data33 = data.iloc[3013:3113]
data34 = data.iloc[3113:3213]
data35 = data.iloc[3213:3313]
data36 = data.iloc[3313:3413]
data37 = data.iloc[3413:3513]
data38 = data.iloc[3513:3613]
data39 = data.iloc[3613:3713]
data40 = data.iloc[3713:3813]

# %%
data1['Text']
# Out:
# 0     b RT Happy Birthday Suga xf x f x e x n nSuga ...
# 1                                          b Check sock
# 2     b RT Lots purple galaxy stuff namjoon hand wri...
# 3     b RT Happy Birthday Suga xf x f x e x n nSuga ...
# 4           b RT except bighit artists chaotic ceo like
#                             ...
# 95    b RT xf x f xa x bbeomgyu birthday layout make...
# 96    b RT VIDEO Q What factors helped reach goals s...
# 97    b RT VIDEO Q What factors helped reach goals s...
# 98    b RT PlEASE TREAT JIN FAIRLY n n naren one ent...
# 99    b RT Playing xe x x c xe x x repeat day Happy ...
# Name: Text, Length: 100, dtype: object

# %%
words= []; words1 = [];words2 = [];words3 = [];words4 = [];words5 = [];words6 = [];words7 = [];words8 = [];words9 = [];words10 = []; 
words11 = [];words12 = [];words13 = [];words14 = [];words15 = [];words16 = [];words17 = [];words18 = [];words19 = [];words20 = []; 
words21 = [];words22 = [];words23 = [];words24 = [];words25 = [];words26 = [];words27 = [];words28 = [];words29 = [];words30 = []; 
words31 = [];words32 = [];words33 = [];words34 = [];words35 = [];words36 = [];words37 = [];words38 = [];words39 = [];words40 = []
for i in data1['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words1.append(j)

for i in data2['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words2.append(j)
            
for i in data3['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words3.append(j)
            
for i in data4['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words4.append(j)
            
for i in data5['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words5.append(j)
            
for i in data6['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words6.append(j)
            
for i in data7['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words7.append(j)
            
for i in data8['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words8.append(j)
            
for i in data9['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words9.append(j)
            
for i in data10['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words10.append(j)
            
for i in data11['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words11.append(j)
            
for i in data12['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words12.append(j)
            
for i in data13['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words13.append(j)
            
for i in data14['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words14.append(j)
            
for i in data15['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words15.append(j)
            
for i in data16['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words16.append(j)
            
for i in data17['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words17.append(j)
            
for i in data18['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words18.append(j)
            
for i in data19['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words19.append(j)
            
for i in data20['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words20.append(j)
            
for i in data21['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words21.append(j)
            
for i in data22['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words22.append(j)
            
for i in data23['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words23.append(j)
            
for i in data24['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words24.append(j)
            
for i in data25['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words25.append(j)
            
for i in data26['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words26.append(j)
            
for i in data27['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words27.append(j)
            
for i in data28['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words28.append(j)
            
for i in data29['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words29.append(j)
            
for i in data30['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words30.append(j)
            
for i in data31['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words31.append(j)
            
for i in data32['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words32.append(j)
            
for i in data33['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words33.append(j)
            
for i in data34['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words34.append(j)
            
for i in data35['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words35.append(j)
            
for i in data36['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words36.append(j)
            
for i in data37['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words37.append(j)
            
for i in data38['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words38.append(j)


for i in data39['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words39.append(j)

            
for i in data40['Text']:
    words = i.split()
    for j in words:
        if len(j) > 3:
            words40.append(j)

# %%
from collections import Counter
  
def most_frequent(List):
    occurence_count = Counter(List)
    return occurence_count.most_common(1)[0][0]
    

freq1 = most_frequent(words1)
freq2 = most_frequent(words2)
freq3 = most_frequent(words3)
freq4 = most_frequent(words4)
freq5 = most_frequent(words5)
freq6 = most_frequent(words6)
freq7 = most_frequent(words7)
freq8 = most_frequent(words8)
freq9 = most_frequent(words9)
freq10 = most_frequent(words10)
freq11 = most_frequent(words11)
freq12 = most_frequent(words12)
freq13 = most_frequent(words13)
freq14 = most_frequent(words14)
freq15 = most_frequent(words15)
freq16 = most_frequent(words16)
freq17 = most_frequent(words17)
freq18 = most_frequent(words18)
freq19 = most_frequent(words19)
freq20 = most_frequent(words20)
freq21 = most_frequent(words21)
freq22 = most_frequent(words22)
freq23 = most_frequent(words23)
freq24 = most_frequent(words24)
freq25 = most_frequent(words25)
freq26 = most_frequent(words26)
freq27 = most_frequent(words27)
freq28 = most_frequent(words28)
freq29 = most_frequent(words29)
freq30 = most_frequent(words30)
freq31 = most_frequent(words31)
freq32 = most_frequent(words32)
freq33 = most_frequent(words33)
freq34 = most_frequent(words34)
freq35 = most_frequent(words35)
freq36 = most_frequent(words36)
freq37 = most_frequent(words37)
freq38 = most_frequent(words38)
freq39 = most_frequent(words39)
freq40 = most_frequent(words40)

# %%
Day1 = pd.read_csv('TrendingTopics_Day1.csv')
Day2 = pd.read_csv('TrendingTopics_Day2.csv')
Day3 = pd.read_csv('TrendingTopics_Day3.csv')
Day4 = pd.read_csv('TrendingTopics_Day4.csv')

# %%
Day1.sort_values(by=['tweet_volume'], inplace=True, ascending=False)
Day1.reset_index(inplace = True)
Day2.sort_values(by=['tweet_volume'], inplace=True, ascending=False)
Day2.reset_index(inplace = True)
Day3.sort_values(by=['tweet_volume'], inplace=True, ascending=False)
Day3.reset_index(inplace = True)
Day4.sort_values(by=['tweet_volume'], inplace=True, ascending=False)
Day4.reset_index(inplace = True)

# %%
df1 = Day1.drop(['index', 'Unnamed: 0', 'url', 'promoted_content','query'], axis=1)
top10_Day1 = df1.head(10)
df2 = Day2.drop(['index', 'Unnamed: 0', 'url', 'promoted_content','query'], axis=1)
top10_Day2 = df2.head(10)
df3 = Day3.drop(['index', 'Unnamed: 0', 'url', 'promoted_content','query'], axis=1)
top10_Day3 = df3.head(10)
df4 = Day4.drop(['index', 'Unnamed: 0', 'url', 'promoted_content','query'], axis=1)
top10_Day4 = df4.head(10)

# %%
top10_Day1
# Out:
#                              name  tweet_volume
# 0             #WhatDoYouBelieveIn     1995003.0
# 1                          bighit     1135023.0
# 2                      your video      502767.0
# 3                        baekhyun      482701.0
# 4                        Security      344011.0
# 5                 MAP OF THE SOUL      299628.0
# 6                            HYBE      298808.0
# 7  #IFPIGlobalAlbumAllFormatChart      291353.0
# 8             Congratulations BTS      290528.0
# 9                           Bambi      221151.0

# %%
l1 = []
l2 = []
l3 = []
l4 = []
l1 = top10_Day1['name'].to_list()
l2 = top10_Day2['name'].to_list()
l3 = top10_Day3['name'].to_list()
l4 = top10_Day4['name'].to_list()

# %%
l1
# Out:
# ['#WhatDoYouBelieveIn',
#  'bighit',
#  'your video',
#  'baekhyun',
#  'Security',
#  'MAP OF THE SOUL',
#  'HYBE',
#  '#IFPIGlobalAlbumAllFormatChart',
#  'Congratulations BTS',
#  'Bambi']

# %%
for i in l2 :
    l1.append(i)
len(l1)
# Out:
# 20

# %%
for i in l3 :
    l1.append(i)
len(l1)
# Out:
# 30

# %%
for i in l4 :
    l1.append(i)
len(l1)
# Out:
# 40

# %%
df1 = pd.DataFrame(l1)
df1
# Out:
#                                  0
# 0              #WhatDoYouBelieveIn
# 1                           bighit
# 2                       your video
# 3                         baekhyun
# 4                         Security
# 5                  MAP OF THE SOUL
# 6                             HYBE
# 7   #IFPIGlobalAlbumAllFormatChart
# 8              Congratulations BTS
# 9                            Bambi
# 10                         Happy 1
# 11             #OurProducerBeomgyu
# 12        #50DaysToTHALA50Festival
# 13            #1YearWithSweetNight
# 14                #따뜻하다_범규생일이_오려나봐
# 15           #어여쁜_꽃처럼_피어난_범규의_스물하나
# 16                           Match
# 17          MOST GOOGLED STAR ASIM
# 18                          Jordan
# 19                            T-20
# 20              #지훈이의_스물두번째_봄을_축하해
# 21       #SexyCutieLeaderJihoonDay
# 22          #100DForதளபதிVIJAYBday
# 23         #puneethrajkumarbdaycdp
# 24               #7YearsOfJANASENA
# 25          Kolkata On Roads 4 SSR
# ...

# %%
freq8
# Out:
# 'Congratulations'

# %%
df1.insert(1, "Common_Words",[freq1,freq2,freq3,freq4,freq5,freq6,freq7,freq8,freq9,freq10,freq11,freq12,
                             freq13,freq14,freq15,freq16,freq17,freq18,freq19,freq20,freq21,freq22,freq23,
                              freq24,freq25,freq26,freq27,freq28,freq29,freq30,freq31,freq32,freq33,freq34,
                              freq35,freq36,freq37,freq38,freq39,freq40], True)
                              
df1
# Out:
#                                  0           Common_Words
# 0              #WhatDoYouBelieveIn                  South
# 1                           bighit                  video
# 2                       your video               baekhyun
# 3                         baekhyun               security
# 4                         Security                   Love
# 5                  MAP OF THE SOUL                  Music
# 6                             HYBE               tomorrow
# 7   #IFPIGlobalAlbumAllFormatChart        Congratulations
# 8              Congratulations BTS                  Bambi
# 9                            Bambi                  drama
# 10                         Happy 1                  happy
# 11             #OurProducerBeomgyu     OurProducerBeomgyu
# 12        #50DaysToTHALA50Festival                   YEAR
# 13            #1YearWithSweetNight                  match
# 14                #따뜻하다_범규생일이_오려나봐                  trend
# ...

# %%
df1.rename(columns = {0:'Topics'}, inplace = True)

# %%
df1
# Out:
#                             Topics           Common_Words
# 0              #WhatDoYouBelieveIn                  South
# 1                           bighit                  video
# 2                       your video               baekhyun
# 3                         baekhyun               security
# 4                         Security                   Love
# 5                  MAP OF THE SOUL                  Music
# 6                             HYBE               tomorrow
# 7   #IFPIGlobalAlbumAllFormatChart        Congratulations
# 8              Congratulations BTS                  Bambi
# 9                            Bambi                  drama
# 10                         Happy 1                  happy
# 11             #OurProducerBeomgyu     OurProducerBeomgyu
# 12        #50DaysToTHALA50Festival                   YEAR
# 13            #1YearWithSweetNight                  match
# 14                #따뜻하다_범규생일이_오려나봐                  trend
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\basua\anaconda3\python.exe

# %%
import wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''
stopwords = set(STOPWORDS)
  
# iterate through the csv file
for val in df1.Common_Words:
      
    # typecaste each val to string
    val = str(val)
  
    # split the value
    tokens = val.split()
      
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
  
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()

# %%
df1.to_csv('MostCommonWord.csv')
