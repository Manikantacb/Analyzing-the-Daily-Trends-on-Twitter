# %%
import pandas as pd

# %%
topics = pd.read_csv('Trendingtopics_Combined.csv')
topics
# Out:
#                                name  tweet_volume
# 0                    #MamtaBanerjee           NaN
# 1             #1MOTS7AlbumAllFormat      191017.0
# 2    #IFPIGlobalAlbumAllFormatChart      291353.0
# 3             Stop Fake News On SSR       44065.0
# 4               #WhatDoYouBelieveIn     1995003.0
# ..                              ...           ...
# 195                      #TeamIndia       19117.0
# 196     #FakeTheoryInIslamOnRebirth      290160.0
# 197                      #AskHimesh           NaN
# 198                   #LightItUpBTS       81252.0
# 199         #HappyBirthdayAliaBhatt       11023.0
#
# [200 rows x 2 columns]

# %%
topics.sort_values(by=['tweet_volume'], inplace=True, ascending=False)
topics.reset_index(inplace = True)
topics
# Out:
#      index                       name  tweet_volume
# 0        4        #WhatDoYouBelieveIn     1995003.0
# 1       17                     bighit     1135023.0
# 2      157                    Grammys     1126729.0
# 3      146         #지훈이의_스물두번째_봄을_축하해      873776.0
# 4      145  #SexyCutieLeaderJihoonDay      861286.0
# ..     ...                        ...           ...
# 195    188                 Sam Curran           NaN
# 196    189                      Bhuvi           NaN
# 197    190                   Fielding           NaN
# 198    191                     Bumrah           NaN
# 199    197                 #AskHimesh           NaN
#
# [200 rows x 3 columns]

# %%
df = topics.drop(['index'], axis=1)
top10 = df.head(10)
top10
# Out:
#                         name  tweet_volume
# 0        #WhatDoYouBelieveIn     1995003.0
# 1                     bighit     1135023.0
# 2                    Grammys     1126729.0
# 3         #지훈이의_스물두번째_봄을_축하해      873776.0
# 4  #SexyCutieLeaderJihoonDay      861286.0
# 5                    Happy 1      692506.0
# 6                      Debut      591186.0
# 7        #OurProducerBeomgyu      565357.0
# 8                 your video      502767.0
# 9                   baekhyun      482701.0

# %%
import matplotlib.pyplot as plt
name = top10['name']
tweet_volume = top10['tweet_volume']
# Figure Size
fig, ax = plt.subplots(figsize =(10, 8))
 
# Horizontal Bar Plot
ax.barh(name, tweet_volume)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
#Add Plot Title
ax.set_title('Top 10 Trending Topics',
             loc ='left', )
# Out:
# Text(0.0, 1.0, 'Top 10 Trending Topics')

# %%
top10.to_csv('Trendingtopics(Descending).csv')
